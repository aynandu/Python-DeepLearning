# %%
import numpy as np  # For Algebric Expressions
import matplotlib.pyplot as plt  # for Graphical Representation

# %%
time = np.linspace(0,40,1000) # start , finish , a points

# %% [markdown]
# Distance travelled by robber ; driving a car at 150/hr
#    dst_rob=2.5time

# %%
dst_rob =  2.5*time

# %% [markdown]
# Distance Travelled by Sheriff : dis_sherf = 3(t-5)  driving a car at 180/hr

# %%
dis_sherf=3 *(time-5)

# %%
fig , ax = plt.subplots()
plt.title("A Bank Robber Caught - Solution Example")
plt.xlabel("time (in minutes)")
plt.ylabel("distance (in km)")
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(time,dst_rob,'green')
ax.plot(time,dis_sherf,"red")
plt.axvline(x=30,color="purple",linestyle='--')
__=plt.axhline(y=75,color="purple",linestyle='--')

# %% [markdown]
# Excercise 2 -  Jilla Solar Panal April ! - mark 1 produed 1Kj/day May 1 Mark2 produced 4Kj/day

# %%
day = np.linspace(1,60,1000) # Month 1 start , month 2 finish , a points

# %% [markdown]
# Jills Solar Panal - Mark One : 1KJ/day

# %%
mark_l=1*day

# %% [markdown]
# Jills Solar Panal - Mark Two : 4
# KJ/day-30

# %%
mark_2=4*(day-30)

# %%
axs=plt.subplot()
plt.title("Jill's Mark I vs Mark II Solar Panal - Solution" )
plt.xlabel("No: of Days")
plt.ylabel("No; of KJ")
axs.set_xlim([1,60])
axs.set_ylim([1,100])
plt.plot(day,mark_l,"green")
plt.plot(day,mark_2,"red")
plt.axvline(x=40,color="pink",linestyle="--")
__=plt.axhline(y=40,color="pink",linestyle="--")

# %% [markdown]
# 1.Mark I Generate 40Kj on 40th day; Mark II Generate 40Kj on 10 days.
# 2.40 days (Mark I (April1 - May 10) :40 Kj ; Mark II (May 1 -May 10): 40 Kj) 80Kj produced from both
# 3.IF MARK I & Mark II = 1kj/day thet it will be a No Solution

# %% [markdown]
# Vector (Rank 1 Tensors) in Numpy

# %%
x=np.array([25,2,5]) # type argument is optional , eg:dtype=np.float16
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
x[0]
# Out:
# 25

# %%
type(x[0])
# Out:
# numpy.int32

# %%
x_t=x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
y=np.array([[25,2,5]]) # ....but it does  we use nested "matrix - style " brackets :
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
y_t=y.T #.. but can transpose a matrixs with a dimension of length 1 , which is mathematically equivalent:
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape # this is an column vector as it has 3 rows and one column
# Out:
# (3, 1)

# %% [markdown]
# NORMS & UNIT VECTOR

# %% [markdown]
# Norms are functions  that quantify vector magnitude.
# Magnitude means size or length of the vector.

# %% [markdown]
# L2 Norms -

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %%
#using L2 Norms
np.linalg.norm(x)
# Out:
# 25.573423705088842

# %% [markdown]
# So, if units  in this 3 -dimentional vector space are meters, then the vector x has a length of 25.6 m

# %%
#Excercise
x_tr=np.array([25,2,-3,-23])
x_tr
# Out:
# array([ 25,   2,  -3, -23])

# %%
x_tra = x_tr.T
x_tra
# Out:
# array([ 25,   2,  -3, -23])
